# %% [markdown]
# # PROYECTO - Análisis de Conflictos Históricos Religiosos o Culturales
#
# # MOTIVACIONES GENERALES
# - Comprender la importancia de la convivencia pacífica y el respeto en un entorno multicultural y diverso.
# - Analizar y reflexionar sobre la doctrina social de diferentes religiones.
# - Desarrollar estrategias de solución para resolver conflictos por motivos religiosos.
# - Trabajar en equipo y fomentar el aprendizaje colaborativo.
# - Presentar una propuesta con estrategias de solución a un conflicto por motivos religiosos.
#
#
# # Motivaciones del Proyecto
#
# 1. Relevancia de los Datos
# El Uppsala Conflict Data Program (UCDP) proporciona datos detallados sobre conflictos armados, lo que es crucial para el estudio de la paz y los conflictos. La información obtenida de estos datos puede ayudar a los investigadores, analistas y formuladores de políticas a comprender mejor las dinámicas de los conflictos y trabajar hacia soluciones para prevenir o resolver estos conflictos.
#
# 2. Análisis de Tendencias Globales
# Al analizar datos sobre conflictos armados, podemos identificar patrones y tendencias globales a lo largo del tiempo. Esto incluye el aumento o disminución de conflictos en ciertas regiones, los factores que contribuyen a la violencia y las consecuencias de las intervenciones políticas y militares.
#
# 3. Impacto Humanitario
# Los datos del UCDP incluyen detalles sobre el número de muertes y la ubicación de los incidentes, lo que permite un análisis profundo del impacto humanitario de los conflictos. Este análisis puede ayudar a las organizaciones no gubernamentales (ONGs) y a las agencias internacionales a dirigir mejor sus esfuerzos de ayuda y respuesta.
#
# 4. Innovación en Procesos ETL
# Realizar un proyecto ETL con estos datos proporciona una oportunidad para mejorar y automatizar procesos de extracción, transformación y carga de datos. Desarrollar habilidades en estas áreas es valioso para cualquier profesional de datos y puede ser aplicado en una amplia variedad de contextos y sectores.
#
# 5. Visualización y Comunicación
# Una vez transformados y cargados, los datos pueden ser visualizados de manera efectiva para comunicar hallazgos importantes a una audiencia más amplia. Esto puede incluir visualizaciones interactivas que permitan a los usuarios explorar los datos por sí mismos, así como gráficos y mapas que resuman las tendencias y hallazgos clave.
#
# 6. Contribución a la Investigación Académica
# Los resultados del proyecto pueden ser utilizados para respaldar investigaciones académicas sobre conflictos armados. Los datos del UCDP son ampliamente citados en la literatura académica, y un análisis riguroso y bien documentado puede contribuir significativamente a este campo de estudio.
#
# 7. Sensibilización y Educación
# A través de la visualización y el storytelling, podemos sensibilizar al público sobre la realidad de los conflictos armados en el mundo. Esto puede fomentar una mayor conciencia y comprensión, lo que es un paso importante hacia la promoción de la paz y la resolución de conflictos.
#
# 8. Desarrollo Profesional
# Trabajar en este proyecto proporciona una experiencia valiosa en el manejo de datos reales y complejos, mejorando habilidades técnicas y analíticas que son altamente demandadas en el mercado laboral. También fomenta la capacidad de trabajar en equipo y gestionar proyectos de datos de principio a fin.
#
#                                   - Conclusión
# Las motivaciones para este proyecto ETL son múltiples y variadas, abarcando desde el impacto social y humanitario hasta el desarrollo profesional y la innovación técnica. Al abordar este proyecto, no solo contribuimos al conocimiento y la investigación en el campo de los conflictos armados, sino que también desarrollamos habilidades críticas y creamos herramientas útiles para una amplia gama de aplicaciones futuras.

# %% [markdown]
#                                   # Alcance del Proyecto
#      Objetivos Principales:
#
# # Extracción de Datos:
#
# Automatizar la extracción de datos desde la página web del UCDP.
# Identificar y descargar todos los archivos relevantes (principalmente archivos zip que contienen datos CSV).
# Transformación de Datos:
#
# Limpiar y estructurar los datos extraídos para garantizar su calidad y coherencia.
# Crear nuevas variables si es necesario para enriquecer el análisis.
# Carga de Datos:
#
# Cargar los datos transformados a una base de datos en Airtable.
# Establecer métodos automatizados para la carga y extracción de datos desde Airtable usando su API.
# Visualización de Datos:
#
# Generar gráficos y visualizaciones interactivos para comunicar los hallazgos de los datos.
# Usar librerías de visualización como matplotlib, seaborn, plotly y folium.
# Storytelling:
#
# Presentar una narrativa coherente sobre el proceso y los resultados del proyecto.
# Incluir visualizaciones y explicaciones detalladas sobre el análisis realizado.
#
#        Datos Utilizados:
# Datos de conflictos armados proporcionados por el UCDP, incluyendo detalles como fechas, ubicaciones, y número de muertes.

# %% [markdown]
# # Herramientas o Tecnologías Usadas
#
#     Lenguajes y Librerías:
#     Python:
#     Requests: Para la descarga de contenido HTML y archivos.
#     BeautifulSoup: Para el scraping y análisis del HTML.
#     ZipFile: Para la extracción de archivos zip.
#     Pandas: Para la manipulación y análisis de datos.
#     NumPy: Para operaciones numéricas.
#     Matplotlib y Seaborn: Para visualización de datos.
#     Plotly: Para visualizaciones interactivas.
#     Folium: Para la creación de mapas interactivos.
#     Servicios:
#     Airtable:
#     Para la carga y almacenamiento de datos mediante su API.

# %% [markdown]
# # Desafíos en Cada Parte del Proceso
#
# 1. Extracción de Datos:
# Identificación de Enlaces de Descarga:
#
# Desafío: Encontrar todos los enlaces de descarga de archivos zip dentro de la página web.
# Solución: Uso de BeautifulSoup para analizar el HTML y filtrar enlaces que contengan archivos zip.
# Descarga de Archivos:
#
# Desafío: Manejar posibles interrupciones o errores durante la descarga.
# Solución: Implementar manejo de excepciones y reintentos para asegurar la descarga completa de archivos.
#
# 2. Transformación de Datos:
# Limpieza de Datos:
#
# Desafío: Manejar datos faltantes, duplicados y errores en los datos extraídos.
# Solución: Uso de pandas para identificar y corregir problemas en los datos, incluyendo la eliminación de duplicados y la imputación de valores faltantes.
# Estructuración de Datos:
#
# Desafío: Convertir formatos de fecha y otros tipos de datos para garantizar la coherencia.
# Solución: Uso de pandas para transformar columnas de fechas y normalizar otros tipos de datos.
# Creación de Nuevas Variables:
#
# Desafío: Determinar qué nuevas variables podrían ser útiles para el análisis.
# Solución: Análisis exploratorio de datos para identificar oportunidades para crear nuevas variables.
#
# 3. Carga de Datos:
# Interacción con API de Airtable:
#
# Desafío: Configurar y autenticar correctamente la API de Airtable.
# Solución: Uso de la documentación de Airtable para establecer la autenticación y realizar operaciones CRUD (Crear, Leer, Actualizar, Eliminar).
# Automatización de Procesos:
#
# Desafío: Asegurar que los procesos de carga y extracción sean automáticos y robustos.
# Solución: Desarrollo de funciones reutilizables en Python para interactuar con la API de Airtable.
#
# 4. Visualización de Datos:
# Generación de Visualizaciones Interactivas:
#
# Desafío: Crear visualizaciones que sean informativas y fáciles de interpretar.
# Solución: Uso de librerías avanzadas como Plotly y Folium para crear gráficos y mapas interactivos.
# Personalización de Gráficos:
#
# Desafío: Ajustar visualizaciones para resaltar hallazgos importantes y mejorar la presentación.
# Solución: Ajuste de parámetros y estilos en matplotlib y seaborn, y uso de funcionalidades interactivas en Plotly.
#
# 5. Storytelling:
# Estructuración de la Presentación:
#
# Desafío: Organizar la narrativa para que sea clara y coherente.
# Solución: Desarrollar un esquema detallado de la presentación que incluya todos los pasos del proyecto, desde la motivación hasta los resultados.
# Comunicación de Resultados:
#
# Desafío: Asegurar que los hallazgos y conclusiones sean comprensibles para una audiencia no técnica.
# Solución: Uso de gráficos claros y explicaciones detalladas sobre el significado de los resultados.

# %% [markdown]
# # Resolución de Cada Desafío o Problema

# %%
# Resolución de Cada Desafío o Problema

1. Extracción de Datos
Desafío: Identificación de Enlaces de Descarga

Problema: Encontrar todos los enlaces de descarga de archivos zip dentro de la página web.
Solución: Utilizamos BeautifulSoup para analizar el HTML y filtrar enlaces que contengan archivos zip.
python
Copiar código
def find_download_links(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    links = soup.find_all('a', href=True)
    download_links = [link['href'] for link in links if '.zip' in link['href']]
    return download_links
Desafío: Descarga de Archivos

Problema: Manejar posibles interrupciones o errores durante la descarga.
Solución: Implementamos manejo de excepciones y reintentos para asegurar la descarga completa de archivos.
python
Copiar código
def download_file(url, dest_path):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Verifica si hay errores
        with open(dest_path, 'wb') as file:
            file.write(response.content)
    except requests.exceptions.RequestException as e:
        print(f"Error downloading {url}: {e}")
2. Transformación de Datos
Desafío: Limpieza de Datos

Problema: Manejar datos faltantes, duplicados y errores en los datos extraídos.
Solución: Usamos pandas para identificar y corregir problemas en los datos, incluyendo la eliminación de duplicados y la imputación de valores faltantes.
python
Copiar código
def clean_data(df):
    df.drop_duplicates(inplace=True)
    df.fillna(method='ffill', inplace=True)  # Forward fill para valores faltantes
    return df
Desafío: Estructuración de Datos

Problema: Convertir formatos de fecha y otros tipos de datos para garantizar la coherencia.
Solución: Usamos pandas para transformar columnas de fechas y normalizar otros tipos de datos.
python
Copiar código
def transform_data(df):
    df['date'] = pd.to_datetime(df['date'], errors='coerce')
    return df
Desafío: Creación de Nuevas Variables

Problema: Determinar qué nuevas variables podrían ser útiles para el análisis.
Solución: Realizamos un análisis exploratorio de datos para identificar oportunidades para crear nuevas variables.
python
Copiar código
def create_new_variables(df):
    df['year'] = df['date'].dt.year
    df['month'] = df['date'].dt.month
    return df
3. Carga de Datos
Desafío: Interacción con API de Airtable

Problema: Configurar y autenticar correctamente la API de Airtable.
Solución: Usamos la documentación de Airtable para establecer la autenticación y realizar operaciones CRUD.
python
Copiar código
def airtable_upload(df, base_id, table_name, api_key):
    url = f"https://api.airtable.com/v0/{base_id}/{table_name}"
    headers = {"Authorization": f"Bearer {api_key}", "Content-Type": "application/json"}
    
    for index, row in df.iterrows():
        record = {"fields": row.to_dict()}
        response = requests.post(url, json=record, headers=headers)
        if response.status_code != 200:
            print(f"Error uploading record {index}: {response.content}")
Desafío: Automatización de Procesos

Problema: Asegurar que los procesos de carga y extracción sean automáticos y robustos.
Solución: Desarrollamos funciones reutilizables en Python para interactuar con la API de Airtable.
4. Visualización de Datos
Desafío: Generación de Visualizaciones Interactivas

Problema: Crear visualizaciones que sean informativas y fáciles de interpretar.
Solución: Usamos librerías avanzadas como Plotly y Folium para crear gráficos y mapas interactivos.
python
Copiar código
import plotly.express as px

def plot_conflict_trends(df):
    fig = px.line(df, x='year', y='number_of_conflicts', title='Trends in Armed Conflicts')
    fig.show()
Desafío: Personalización de Gráficos

Problema: Ajustar visualizaciones para resaltar hallazgos importantes y mejorar la presentación.
Solución: Ajustamos parámetros y estilos en matplotlib y seaborn, y usamos funcionalidades interactivas en Plotly.
python
Copiar código
import matplotlib.pyplot as plt
import seaborn as sns

def plot_conflict_deaths(df):
    plt.figure(figsize=(10, 6))
    sns.barplot(data=df, x='year', y='number_of_deaths')
    plt.title('Number of Deaths per Year in Armed Conflicts')
    plt.xlabel('Year')
    plt.ylabel('Number of Deaths')
    plt.show()
5. Storytelling
Desafío: Estructuración de la Presentación

Problema: Organizar la narrativa para que sea clara y coherente.
Solución: Desarrollamos un esquema detallado de la presentación que incluya todos los pasos del proyecto, desde la motivación hasta los resultados.
Desafío: Comunicación de Resultados

Problema: Asegurar que los hallazgos y conclusiones sean comprensibles para una audiencia no técnica.
Solución: Usamos gráficos claros y explicaciones detalladas sobre el significado de los resultados.
Esquema del Proyecto
Introducción:

Motivaciones del proyecto.
Descripción del alcance del proyecto.
Extracción de Datos:

Proceso de identificación y descarga de archivos desde la página web.
Técnicas de scraping y descarga automática de archivos zip.
Transformación de Datos:

Proceso de limpieza y estructuración de datos.
Creación de nuevas variables y preparación para el análisis.
Carga de Datos:

Configuración y uso de la API de Airtable.
Proceso de carga y extracción automatizada de datos.
Visualización de Datos:

Creación de gráficos y mapas interactivos.
Análisis de tendencias y hallazgos importantes.
Storytelling:

Presentación de la narrativa del proyecto.
Explicación de visualizaciones y resultados.
Conclusiones:

Resumen de los hallazgos.
Reflexión sobre el impacto y aplicaciones futuras del proyecto.

# %% [markdown]
# # Esquema del Proyecto
# Introducción:
#
#      Motivaciones del proyecto.
# Descripción del alcance del proyecto.
# Extracción de Datos:
#
#       Proceso de identificación y descarga de archivos desde la página web.
# Técnicas de scraping y descarga automática de archivos zip.
# Transformación de Datos:
#
#       Proceso de limpieza y estructuración de datos.
# Creación de nuevas variables y preparación para el análisis.
# Carga de Datos:
#
#      Configuración y uso de la API de Airtable.
# Proceso de carga y extracción automatizada de datos.
# Visualización de Datos:
#
#      Creación de gráficos y mapas interactivos.
# Análisis de tendencias y hallazgos importantes.
# Storytelling:
#
#      Presentación de la narrativa del proyecto.
# Explicación de visualizaciones y resultados.
# Conclusiones:
#
#       Resumen de los hallazgos.
# Reflexión sobre el impacto y aplicaciones futuras del proyecto.

# %% [markdown]
# # Visualizaciones y Resultados
#
# 1. Tendencias en Conflictos Armados
# Gráfico de Líneas: Muestra las tendencias de conflictos armados a lo largo de los años.
# python
#
# Copiar código
# def plot_conflict_trends(df):
#     fig = px.line(df, x='year', y='number_of_conflicts', title='Trends in Armed Conflicts')
#     fig.show()
#
# 2. Número de Muertes por Año
#
# Gráfico de Barras: Muestra el número de muertes por año en conflictos armados.
# python
#
# Copiar código
# def plot_conflict_deaths(df):
#     plt.figure(figsize=(10, 6))
#     sns.barplot(data=df, x='year', y='number_of_deaths')
#     plt.title('Number of Deaths per Year in Armed Conflicts')
#     plt.xlabel('Year')
#     plt.ylabel('Number of Deaths')
#     plt.show()
#
# 3. Distribución Geográfica de los Conflictos
#
# Mapa Interactivo: Muestra la distribución geográfica de los conflictos usando Folium.
# python
#
# Copiar código
# import folium
#
# def plot_conflict_map(df):
#     m = folium.Map(location=[0, 0], zoom_start=2)
#
#     for _, row in df.iterrows():
#         folium.Marker([row['latitude'], row['longitude']],
#                       popup=f"Conflict: {row['conflict_name']}").add_to(m)
#
#     m.save('conflict_map.html')
#
# Estas visualizaciones ayudan a comunicar de manera efectiva las tendencias, impactos y distribuciones de los conflictos armados a lo largo del tiempo y geográficamente.
